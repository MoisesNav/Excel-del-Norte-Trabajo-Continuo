# %%
import requests 
url = "https://api01.exeldelnorte.com.mx/almacenes" 
payload={} 
headers = { 
  'Authorization': 'API_6ee6a508bb7ebd80d19ef1d6edf141354cade0f7' 
}
 
response = requests.request("GET", url, headers=headers, data=payload) 
print(response.text)
# Out:
# {"resultado":true,"mensaje":"Datos 29","datos":[{"clave":"CH","nombre":"CHIHUAHUA","direccion":{"calle":"Heroico Colegio Militar","numero exterior":"3705","numero interior":"Bodega B","colonia":"Nombre de Dios","codigo postal":"31150","ciudad":"Chihuahua","estado":"Chihuahua"},"tranportistas":[{"clave":"ESTT","nombre":"ESTAFETA (TARIMA)"},{"clave":"GPCL","nombre":"GUIA PAGADA POR CLTE "},{"clave":"MDHL","nombre":"DHL"},{"clave":"MEXP","nombre":"MENSAJERIA EXPRESS"},{"clave":"POTT","nombre":"POTOSINOS (TARIMA)"},{"clave":"REXT","nombre":"RED EXPRESS (TARIMA) "},{"clave":"SEPO","nombre":"SERV. ESP EN PORTEO "},{"clave":"SEXP","nombre":"SENDA EXPRESS"},{"clave":"TPIX","nombre":"PITIC (TARIMAS) "},{"clave":"PRCL","nombre":"PROPIO DEL CLIENTE"},{"clave":"EX01","nombre":"REPARTO LOCAL EXEL"},{"clave":"ESTA","nombre":"ESTAFETA 5kg"},{"clave":"FEDX","nombre":"FEDERAL EXPRESS"}]},{"clave":"GD","nombre":"GUADALAJARA","direccion":{"calle":"Calle 3","numero exterior":"1090","numero interior":null,"colonia":"Zona Industrial","codigo postal":"44940","ciudad":"Guadalajara","estado":"Jalisco"},"tranportistas":[{"clave":"ESTT","nombre":"ESTAFETA (TARIMA)"},{"clave":"GPCL","nombre":"GUIA PAGADA POR CLTE "},{"clave":"MDHL","nombre":"DHL"},{"clave":"POTT","nombre":"POTOSINOS (TARIMA)"},{"clave":"REXT","nombre":"RED EXPRESS (TARIMA) "},{"clave":"SEXP","nombre":"SENDA EXPRESS"},{"clave":"SREX","nombre":"SERVICIO EXPRESS(NEL "},{"clave":"PRCL","nombre":"PROPIO DEL CLIENTE"},{"clave":"EX01","nombre":"REPARTO LOCAL EXEL"},{"clave":"ESTA","nombre":"ESTAFETA 5kg"},{"clave":"FEDX","nombre":"FEDERAL EXPRESS"}]},{"clave":"LG","nombre":"LEON","direccion":{"calle":"Jos\u00e9 Mar\u00eda Morelos","numero exterior":"4430","numero interior":null,"colonia":"Fracc. Las Cruces","codigo postal":"37290","ciudad":"Le\u00f3n","estado":"Guanajuato"},"tranportistas":[{"clave":"ESTT","nombre":"ESTAFETA (TARIMA)"},{"clave":"GPCL","nombre":"GUIA PAGADA POR CLTE "},{"clave":"MDHL","nombre":"DHL"},{"clave":"POTT","nombre":"POTOSINOS (TARIMA)"},{"clave":"REXT","nombre":"RED EXPRESS (TARIMA) "},{"clave":"SEXP","nombre":"SENDA EXPRESS"},{"clave":"PRCL","nombre":"PROPIO DEL CLIENTE"},{"clave":"EX01","nombre":"REPARTO LOCAL EXEL"},{"clave":"ESTA","nombre":"ESTAFETA 5kg"},{"clave":"FEDX","nombre":"FEDERAL EXPRESS"}]},{"clave":"MD","nombre":"MERIDA","direccion":{"calle":"Tablaje Catastral","numero exterior":"23435","numero interior":"3 y 4","colonia":"Carretera DZTYA-SAN ANTONIO OOL","codigo postal":"97300","ciudad":"M\u00e9rida","estado":"Yucat\u00e1n"},"tranportistas":[{"clave":"DYPA","nombre":"DYPACK"},{"clave":"ESTT","nombre":"ESTAFETA (TARIMA)"},{"clave":"GPCL","nombre":"GUIA PAGADA POR CLTE "},{"clave":"MDHL","nombre":"DHL"},{"clave":"POTT","nombre":"POTOSINOS (TARIMA)"},{"clave":"REXT","nombre":"RED EXPRESS (TARIMA) "},{"clave":"SEXP","nombre":"SENDA EXPRESS"},{"clave":"PRCL","nombre":"PROPIO DEL CLIENTE"},{"clave":"EX01","nombre":"REPARTO LOCAL EXEL"},{"clave":"ESTA","nombre":"ESTAFETA 5kg"},{"clave":"FEDX","nombre":"FEDERAL EXPRESS"}]},{"clave":"MX","nombre":"MEXICO","direccion":{"calle":"Poniente 134, entre Norte 35 y 45","numero exterior":"580","numero interior":"Letra B","colonia":"Industrial Vallejo Delegaci\u00f3n Azcapotzalco","codigo postal":"02300 ","ciudad":"M\u00e9xico, D.F","estado":"Distrito Federal"},"tranportistas":[{"clave":"ESTT","nombre":"ESTAFETA (TARIMA)"},{"clave":"GPCL","nombre":"GUIA PAGADA POR CLTE "},{"clave":"MDHL","nombre":"DHL"},{"clave":"POTT","nombre":"POTOSINOS (TARIMA)"},{"clave":"REXT","nombre":"RED EXPRESS (TARIMA) "},{"clave":"SEXP","nombre":"SENDA EXPRESS"},{"clave":"PRCL","nombre":"PROPIO DEL CLIENTE"},{"clave":"EX01","nombre":"REPARTO LOCAL EXEL"},{"clave":"ESTA","nombre":"ESTAFETA 5kg"},{"clave":"FEDX","nombre":"FEDERAL EXPRESS"}]},{"clave":"MY","nombre":"MONTERREY","direccion":{"calle":"Av. Sendero","numero exterior":"520","numero interior":"nave B, m\u00f3dulos 6 y ","colonia":"Balcones de An\u00e1huac","codigo postal":"66422","ciudad ...
